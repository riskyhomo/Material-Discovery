# %% [markdown]
# <a href="https://colab.research.google.com/github/riskyhomo/Material-Discovery/blob/main/work_on_this.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/100.csv")
df
# Out:
#     Unnamed: 0  Unnamed: 0.1  Composition  MaterialId  Reduced Formula  \
# 0            0             0       209231           0            39871
# 1            1             1       355560           1           220471
# 2            2             2       173457           2           143223
# 3            3             3       344245           3           364467
# 4            4             4       254904           4            78813
# ..         ...           ...          ...         ...              ...
# 95          95            95       332342          95           142017
# 96          96            96       111270          96            35982
# 97          97            97        69830          97           369497
# 98          98            98       274981          98           174276
# 99          99            99       117919          99           110477
#
#     Elements  NSites    Volume  Density  Point Group  ...  Crystal System  \
# 0     163207      10  302.9202   3.2834           10  ...               2
# 1     181188      16  430.2851   6.8040            8  ...               5
# 2      83526      36  828.6647  12.7292            8  ...               5
# 3     102592      17  407.2614   8.6776            0  ...               5
# 4     176755      36  727.5283   6.9851            8  ...               5
# ..       ...     ...       ...      ...          ...  ...             ...
# 95    181587      21  326.9231   8.6819           13  ...               6
# 96     30932      28  279.1767   3.7338            9  ...               2
# 97    205108      34  626.6744   9.2638           27  ...               2
# 98    165670      16  371.3406   6.5559           30  ...               3
# 99     71378      16  421.2335   9.3758            9  ...               2
#
#     Corrected Energy  Formation Energy Per Atom  \
# 0           -70.4155                    -1.9058
# 1           -94.0804                    -0.5004
# 2          -237.6016                    -1.2960
# 3           -93.6931                    -0.3064
# 4          -254.0953                    -0.8718
# ..               ...                        ...
# 95         -155.9796                    -0.9409
# 96         -113.3359                    -0.1675
# 97         -245.9219                    -0.7224
# 98          -93.6479                    -0.8241
# 99          -81.9195                    -0.6421
#
#     Decomposition Energy Per Atom  Dimensionality Cheon  Bandgap  Is Train  \
# 0                         -0.1625                     5   0.0023       1.0
# 1                         -0.0137                     3   0.0022       1.0
# 2                         -0.1195                     3      inf       1.0
# 3                         -0.0837                     3   0.0011       1.0
# 4                         -0.0186                     3      inf       1.0
# ..                            ...                   ...      ...       ...
# 95                        -0.0286                     3   0.0042       1.0
# 96                        -0.0114                     5   0.0031       1.0
# 97                        -0.0197                     3   0.0004       1.0
# 98                        -0.0302                     3   0.0035       1.0
# 99                        -0.0135                     3      inf       0.0
#
#     Decomposition Energy Per Atom All  Decomposition Energy Per Atom MP  \
# 0                                 0.0                           -0.1625
# 1                                 0.0                           -0.0137
# 2                                 0.0                           -0.1195
# 3                                -0.0                           -0.0837
# 4                                -0.0                           -0.0186
# ..                                ...                               ...
# 95                                0.0                           -0.0286
# 96                                0.0                           -0.0114
# 97                                0.0                           -0.0197
# 98                               -0.0                           -0.0302
# 99                                0.0                           -0.0135
#
#     Decomposition Energy Per Atom MP OQMD
# 0                                 -0.0733
# 1                                 -0.0106
# 2                                 -0.1185
# 3                                 -0.0772
# 4                                 -0.0176
# ..                                    ...
# 95                                -0.0179
# 96                                -0.0093
# 97                                -0.0166
# 98                                -0.0301
# 99                                -0.0133
#
# [100 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 22 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Unnamed: 0                             100 non-null    int64
#  1   Unnamed: 0.1                           100 non-null    int64
#  2   Composition                            100 non-null    int64
#  3   MaterialId                             100 non-null    int64
#  4   Reduced Formula                        100 non-null    int64
#  5   Elements                               100 non-null    int64
#  6   NSites                                 100 non-null    int64
#  7   Volume                                 100 non-null    float64
#  8   Density                                100 non-null    float64
#  9   Point Group                            100 non-null    int64
#  10  Space Group                            100 non-null    int64
#  11  Space Group Number                     100 non-null    int64
#  12  Crystal System                         100 non-null    int64
#  13  Corrected Energy                       100 non-null    float64
#  14  Formation Energy Per Atom              100 non-null    float64
#  15  Decomposition Energy Per Atom          100 non-null    float64
#  16  Dimensionality Cheon                   100 non-null    int64
#  17  Bandgap                                100 non-null    float64
#  18  Is Train                               100 non-null    float64
#  19  Decomposition Energy Per Atom All      100 non-null    float64
#  20  Decomposition Energy Per Atom MP       100 non-null    float64
#  21  Decomposition Energy Per Atom MP OQMD  100 non-null    float64
# dtypes: float64(10), int64(12)
# memory usage: 17.3 KB

# %%
df.shape
# Out:
# (100, 22)

# %%
latent_dim = 10
input_shape = (df.shape[1], 1)
batch_size = 2048
epochs = 250

# %%
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization, ReLU,LeakyReLU
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from keras.layers import Reshape

# %%
generator = Sequential([
    Dense( 16,input_dim = latent_dim),
    LeakyReLU(0.2),
    BatchNormalization(),
    Dense(128),
    LeakyReLU(0.2),
    BatchNormalization(),
    Dense(256, input_dim= latent_dim),
    LeakyReLU(0.2),
    BatchNormalization()])

# %%
generator.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 16)                176
#
#  leaky_re_lu (LeakyReLU)     (None, 16)                0
#
#  batch_normalization (Batch  (None, 16)                64
#  Normalization)
#
#  dense_1 (Dense)             (None, 128)               2176
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 128)               0
#
#  batch_normalization_1 (Bat  (None, 128)               512
#  chNormalization)
#
#  dense_2 (Dense)             (None, 256)               33024
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 256)               0
#
#  batch_normalization_2 (Bat  (None, 256)               1024
#  chNormalization)
#
# =================================================================
# Total params: 36976 (144.44 KB)
# Trainable params: 36176 (141.31 KB)
# Non-trainable params: 800 (3.12 KB)
# _________________________________________________________________

# %%
degenerator = Sequential([
    Input(shape=(256,1)),
    Dense(128, activation=LeakyReLU(0.2)),
    Dense(64, activation=LeakyReLU(0.2)),
    Dense(16, activation=LeakyReLU(0.2)),
    Dense(1, activation="sigmoid")
])

# %%
degenerator.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 256, 128)          256
#
#  dense_7 (Dense)             (None, 256, 64)           8256
#
#  dense_8 (Dense)             (None, 256, 16)           1040
#
#  dense_9 (Dense)             (None, 256, 1)            17
#
# =================================================================
# Total params: 9569 (37.38 KB)
# Trainable params: 9569 (37.38 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
degenerator.trainable=False
gan_input = Input(shape=(latent_dim,))
gan_output = degenerator(generator(gan_input))
gan = Model(gan_input, gan_output)

degenerator.compile(loss="mean_squared_error", optimizer=Adam(learning_rate=0.01, beta_1=0.5))

# %%
gan.compile(loss="mean_squared_error", optimizer = Adam(learning_rate=0.01, beta_1=0.5))

# %%
gan.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 10)]              0
#
#  sequential (Sequential)     (None, 256)               36976
#
#  sequential_2 (Sequential)   (None, 256, 1)            9569
#
# =================================================================
# Total params: 46545 (181.82 KB)
# Trainable params: 36176 (141.31 KB)
# Non-trainable params: 10369 (40.50 KB)
# _________________________________________________________________

# %%
latent_dim = 10
input_shape = (df.shape[1], 1)
batch_size = 10
epochs = 100

# %%
for epoch in range(epochs):
    # Generate real and fake samples
    idx = np.random.randint(0, 99, size=batch_size)
    real_samples = compositions_scaled[idx]
    noise = np.random.normal(0, 1, size=(batch_size, 10))
    fake_samples = generator.predict(noise, batch_size=batch_size)
    fake_samples = np.mean(fake_samples, axis=1)
    fake_samples= np.expand_dims(fake_samples, axis=1)

    # Train the discriminator
    X = np.concatenate((real_samples, fake_samples), axis=0)
    y = np.concatenate((np.ones((batch_size, 1)), np.zeros((batch_size, 1))), axis=0)

    discriminator_loss = degenerator.train_on_batch(X, y)

    # Train the generator
    noise = np.random.normal(0, 1, size=(batch_size, latent_dim))
    y_gan = np.ones(batch_size)
    generator_loss = gan.train_on_batch(noise, y_gan)
    if epoch % 10 == 0:
        print(f"Epoch {epoch}/{epochs}, Discriminator Loss: {discriminator_loss}, Generator Loss: {generator_loss}")
# Out:
# 1/1 [==============================] - 0s 20ms/step
# Epoch 0/100, Discriminator Loss: 0.24827909469604492, Generator Loss: 0.24193482100963593
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# Epoch 10/100, Discriminator Loss: 0.24758842587471008, Generator Loss: 0.24116499722003937
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# Epoch 20/100, Discriminator Loss: 0.2476070672273636, Generator Loss: 0.24013833701610565
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# Epoch 30/100, Discriminator Loss: 0.24805590510368347, Generator Loss: 0.23928257822990417
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 37ms/step
# Epoch 40/100, Discriminator Loss: 0.24815921485424042, Generator Loss: 0.23859509825706482
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# Epoch 50/100, Discriminator Loss: 0.24744820594787598, Generator Loss: 0.238026425242424
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# Epoch 60/100, Discriminator Loss: 0.2484929859638214, Generator Loss: 0.2369370460510254
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# Epoch 70/100, Discriminator Loss: 0.2497248649597168, Generator Loss: 0.23578090965747833
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# Epoch 80/100, Discriminator Loss: 0.24887128174304962, Generator Loss: 0.23497605323791504
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# Epoch 90/100, Discriminator Loss: 0.24840810894966125, Generator Loss: 0.23356103897094727
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step

# %%
from sklearn.preprocessing  import MinMaxScaler
scaler = MinMaxScaler()
composition= df["Composition"].to_numpy().reshape(-1,1)
compositions_scaled = scaler.fit_transform(composition)

# %%
num_materials = 10
noise = np.random.normal(0, 1, size=(num_materials, latent_dim))
new_compositions_encoded = generator.predict(noise)
new_compositions = scaler.inverse_transform(new_compositions_encoded)

# Print the generated materials
# Print the generated materials
for composition in new_compositions:
    composition_str = ' '.join(map(str, composition))
    print(composition_str)
# Out:
# 1/1 [==============================] - 0s 32ms/step
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.7/184.7 kB 3.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.9/107.9 kB 7.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.7/17.7 MB 50.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.2/101.2 kB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 42.9 MB/s eta 0:00:00
#   Building wheel for chempy (setup.py) ... done
#   Building wheel for pyneqsys (setup.py) ... done
#   Building wheel for pyodesys (setup.py) ... done
#   Building wheel for sym (setup.py) ... done

# %%
import numpy as np

element_symbols = {
    0: 'H', 1: 'He', 2: 'Li', 3: 'Be', 4: 'B', 5: 'C', 6: 'N', 7: 'O', 8: 'F', 9: 'Ne',
    10: 'Na', 11: 'Mg', 12: 'Al', 13: 'Si', 14: 'P', 15: 'S', 16: 'Cl', 17: 'Ar', 18: 'K', 19: 'Ca',
    20: 'Sc', 21: 'Ti', 22: 'V', 23: 'Cr', 24: 'Mn', 25: 'Fe', 26: 'Co', 27: 'Ni', 28: 'Cu', 29: 'Zn',
    30: 'Ga', 31: 'Ge', 32: 'As', 33: 'Se', 34: 'Br', 35: 'Kr', 36: 'Rb', 37: 'Sr', 38: 'Y', 39: 'Zr',
    40: 'Nb', 41: 'Mo', 42: 'Tc', 43: 'Ru', 44: 'Rh', 45: 'Pd', 46: 'Ag', 47: 'Cd', 48: 'In', 49: 'Sn',
    50: 'Sb', 51: 'Te', 52: 'I', 53: 'Xe', 54: 'Cs', 55: 'Ba', 56: 'La', 57: 'Ce', 58: 'Pr', 59: 'Nd',
    60: 'Pm', 61: 'Sm', 62: 'Eu', 63: 'Gd', 64: 'Tb', 65: 'Dy', 66: 'Ho', 67: 'Er', 68: 'Tm', 69: 'Yb',
    70: 'Lu', 71: 'Hf', 72: 'Ta', 73: 'W', 74: 'Re', 75: 'Os', 76: 'Ir', 77: 'Pt', 78: 'Au', 79: 'Hg',
    80: 'Tl', 81: 'Pb', 82: 'Bi', 83: 'Po', 84: 'At', 85: 'Rn', 86: 'Fr', 87: 'Ra', 88: 'Ac', 89: 'Th',
    90: 'Pa', 91: 'U', 92: 'Np', 93: 'Pu', 94: 'Am', 95: 'Cm', 96: 'Bk', 97: 'Cf', 98: 'Es', 99: 'Fm', 100 :'Md', 101 :'Unn' , 102: 'No', 103 :'Lr', 104:'Rf', 105:'Db', 106:'Sg', 107:'Bh', 108:'Hs', 109:'Mt', 110:'Ds', 111:'Rg', 112:'Cn', 113:'Nh', 114:'Fl', 115:'Lv', 116:'Ts', 117:'Og'
}


def composition_to_formula(composition):
    formula = ''
    for i, percentage in enumerate(composition):
        if percentage > 0:
            symbol = element_symbols.get(i, 'Unknown')
            formula += f'{symbol}{int(percentage)}'
    return formula


for composition in new_compositions:
    formula = composition_to_formula(composition)
    print(formula)
# Out:
# ...
